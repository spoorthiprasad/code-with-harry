# %%
#importing of python works
import pandas
pandas.read_csv()

# %%
import math
math.floor(4.2334)
# Out:
# 4

# %%
from math import  sqrt,pi
sqrt(9)
# Out:
# 3.0

# %%
math.sqrt(9)
# Out:
# 3.0

# %%
def welcome():
  print("hey you are welcome from harry")
print(__name__)
if __name__=="__main__":   #begining of runing statement from here
  welcome()  #use of above line will be :idiom is a common pattern used in python scripts to determine wheather the script is being directly or being imported as a module into another script
# Out:
# __main__
# hey you are welcome from harry

# %%
#os module

# %%
import os
if(os.path.exist("data"))
os.mkdir("data")

for i in range(0,100):
  os.mkdir(f"data/Day{i+1}")
# Out:
#   File "<ipython-input-9-29b758ee7c13>", line 2
#     if(os.path.exist("data"))
#                              ^
# SyntaxError: expected ':'

# %%
#local and global variable
x=4
print(x)
def hello():
  x=5
  print(f"the local x is {x}")
  print("hello harry")
print(f"the global x is {x}")
hello()
print(f"the global variable is {x}")
# Out:
# 4
# the global x is 4
# the local x is 5
# hello harry
# the global variable is 4

# %%
#local :defined only inside a function and not applicable outside thee function((y=4))
#global variable:
x=4
print(x)
def hello():
  x=5
  y=(4)

  print(f"the local x is {x}")
  print("hello harry")
print(f"the global x is {x}")
hello()
x=5
print(f"the global variable is {x}")
print(y)
# Out:
# 4
# the global x is 4
# the local x is 5
# hello harry
# the global variable is 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-9218aa61ee72> in <cell line: 14>()
#      12 x=5
#      13 print(f"the global variable is {x}")
# ---> 14 print(y)
#
# NameError: name 'y' is not defined

# %%
#local and global variable
x=4
print(x)
def hello():
  x=5
  print(f"the local x is {x}")
  print("hello harry")
print(f"the global x is {x}")
hello()
x=6
print(f"the global variable is {x}")
# Out:
# 4
# the global x is 4
# the local x is 5
# hello harry
# the global variable is 6

# %%
from re import X
x=10   #global variable :defined outside a function annd accessible by entire code
def my_function():
  y=5   #local variable
  print(y)
my_function()
print(x)  #it print because it is a global variable
print(y)   #causes an error because y is a local variable it is not accessible outside the function
# Out:
# 5
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-b0a67be12866> in <cell line: 10>()
#       8 my_function()
#       9 print(x)  #it print because it is a global variable
# ---> 10 print(y)   #causes an error because y is a local variable it is not accessible outside the function
#
# NameError: name 'y' is not defined

# %%
from re import X
x=10   #global variable :defined outside a function annd accessible by entire code
def my_function():
  global x  #convert local to global variable 3
  x=4
  y=5   #local variable
  print(y)
my_function()
print(x) #here both x are local variable where 10 is replace by 4
# Out:
# 5
# 4

# %%
#kon banega karodpathi
